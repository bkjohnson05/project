# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\bkjoh\OneDrive - Duke University\CS372\!FINAL PROJECTv2\project\docs\results.csv")
df
# Out:
#                    run_name     top1     top5      loss  \
# 0     baseline_frozen_noaug  0.72000  0.93625  1.225130
# 1                frozen_aug  0.60250  0.89375  1.614582
# 2   frozen_aug_weight_decay  0.63000  0.91000  1.469979
# 3  partial_aug_weight_decay  0.70500  0.95125  1.006984
# 4    baseline_partial_noaug  0.77625  0.96625  0.754848
# 5               partial_aug  0.69875  0.94000  1.010568
# 6       baseline_full_noaug  0.84500  0.98625  0.530281
# 7                  full_aug  0.82375  0.98125  0.597114
# 8     full_aug_weight_decay  0.80875  0.98375  0.580010
#
#                                            config
# 0    {"augmentation": false, "weight_decay": 0.0}
# 1     {"augmentation": true, "weight_decay": 0.0}
# 2  {"augmentation": true, "weight_decay": 0.0001}
# 3  {"augmentation": true, "weight_decay": 0.0001}
# 4    {"augmentation": false, "weight_decay": 0.0}
# 5     {"augmentation": true, "weight_decay": 0.0}
# ...

# %%
import matplotlib.pyplot as plt

plt.bar(df["run_name"], df["top1"])
plt.xticks(rotation=45)
plt.title("Top-1 Accuracy by Experiment")
plt.show()

# %%
df.sort_values("top1", ascending=False)
# Out:
#                    run_name     top1     top5      loss  \
# 6       baseline_full_noaug  0.84500  0.98625  0.530281
# 7                  full_aug  0.82375  0.98125  0.597114
# 8     full_aug_weight_decay  0.80875  0.98375  0.580010
# 4    baseline_partial_noaug  0.77625  0.96625  0.754848
# 0     baseline_frozen_noaug  0.72000  0.93625  1.225130
# 3  partial_aug_weight_decay  0.70500  0.95125  1.006984
# 5               partial_aug  0.69875  0.94000  1.010568
# 2   frozen_aug_weight_decay  0.63000  0.91000  1.469979
# 1                frozen_aug  0.60250  0.89375  1.614582
#
#                                            config
# 6    {"augmentation": false, "weight_decay": 0.0}
# 7     {"augmentation": true, "weight_decay": 0.0}
# 8  {"augmentation": true, "weight_decay": 0.0001}
# 4    {"augmentation": false, "weight_decay": 0.0}
# 0    {"augmentation": false, "weight_decay": 0.0}
# 3  {"augmentation": true, "weight_decay": 0.0001}
# ...

# %%
plt.bar(df["run_name"], df["top5"])
plt.xticks(rotation=45)
plt.title("Top-5 Accuracy by Experiment")
plt.show()

# %%
df.sort_values("top5", ascending=False)
# Out:
#                    run_name     top1     top5      loss  \
# 6       baseline_full_noaug  0.84500  0.98625  0.530281
# 8     full_aug_weight_decay  0.80875  0.98375  0.580010
# 7                  full_aug  0.82375  0.98125  0.597114
# 4    baseline_partial_noaug  0.77625  0.96625  0.754848
# 3  partial_aug_weight_decay  0.70500  0.95125  1.006984
# 5               partial_aug  0.69875  0.94000  1.010568
# 0     baseline_frozen_noaug  0.72000  0.93625  1.225130
# 2   frozen_aug_weight_decay  0.63000  0.91000  1.469979
# 1                frozen_aug  0.60250  0.89375  1.614582
#
#                                            config
# 6    {"augmentation": false, "weight_decay": 0.0}
# 8  {"augmentation": true, "weight_decay": 0.0001}
# 7     {"augmentation": true, "weight_decay": 0.0}
# 4    {"augmentation": false, "weight_decay": 0.0}
# 3  {"augmentation": true, "weight_decay": 0.0001}
# 5     {"augmentation": true, "weight_decay": 0.0}
# ...
